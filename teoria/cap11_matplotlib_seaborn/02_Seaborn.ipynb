# %%
# !pip install -q seaborn==0.12.2

# %%
import random
import numpy as np
import pandas as pd
import matplotlib as mat
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
np.__version__
# Out:
# '1.22.2'

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
mat.__version__
# Out:
# '3.7.1'

# %%
import seaborn as sea
sea.__version__
# Out:
# '0.12.2'

# %% [markdown]
# # Criando Gráficos com SEABORN

# %%
# Carregando datasets do seaborn
dados = sea.load_dataset("tips") 
#Restaurante

# %%
dados.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dados.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# joinplot cria plot de 2 variaveis - graficos bi e univariado
sea.jointplot(data = dados, x = 'total_bill', y= 'tip', kind = 'reg')

# %%
# Method implot() - plot com dados e modelos de regressão
sea.lmplot(data = dados, x = 'total_bill', y = 'tip', col = 'smoker')

# %% [markdown]
# ## Construindo um dataframe com Pandas

# %%
df = pd.DataFrame()

# %%
# Alimentando o df com valores aleatorios
df['idade'] = random.sample(range(20,100), 30)
df['peso'] = random.sample(range(55,150), 30)

# %%
df.shape
# Out:
# (30, 2)

# %%
df.head()
# Out:
#    idade  peso
# 0     96   149
# 1     37   122
# 2     54    64
# 3     89   146
# 4     57   116

# %%
# Implot

sea.lmplot(data = df, x = 'idade', y = 'peso', fit_reg = True) #modelo de regressão inclusive

# %%
# Kdeplot

sea.kdeplot(df.idade)
# Out:
# <Axes: xlabel='idade', ylabel='Density'>

# %%
sea.kdeplot(df.peso)
# Out:
# <Axes: xlabel='peso', ylabel='Density'>

# %%
# displot

sea.distplot(df.peso)
# Out:
# <Axes: xlabel='peso', ylabel='Density'>

# %%
# Histograma
plt.hist(df.idade, alpha = .3)
sea.rugplot(df.idade) # "rugas no histograma para mais detalhamento"
# Out:
# <Axes: xlabel='idade'>

# %%
# Box Plot
sea.boxplot(df.idade, color = 'm')
# Out:
# <Axes: >

# %%
# Clustermap

sea.clustermap(df)
