# %% [markdown]
# # Preenchendo valores ausentes em DataFrames do Pandas
#
# A função fillna() é usada para preencher valores ausentes

# %%
import pandas as pd
import numpy as np

# %%
# Importanto o dataset

dataSet = pd.read_csv("dataset.csv")

# %%
dataSet.head(5)
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# ...

# %%
dataSet.isna().sum() # Verifica quantos valores não preenchidos existem por coluna
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      2
# dtype: int64

# %%
moda = dataSet['Quantidade'].value_counts().index[0]

# %%
moda
# Out:
# 3.0

# %%
# Após descobrir a 'moda' dos dados, vamos preencher o valor ausente com o valor

# %%
dataSet['Quantidade'].fillna(value = moda, inplace = True)

# %%
dataSet.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
valorTotal = dataSet['Valor_Venda'].value_counts().sum()

# %%
print(f"Valor total da tabela é R$ {valorTotal},00 ")
# Out:
# Valor total da tabela é R$ 9994,00

# %%
recorrencia = dataSet['Segmento'].value_counts()

# %%
recorrencia
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segmento, dtype: int64

# %% [markdown]
# ## Query (Consulta)

# %%
dataSet.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
#mehtod query()

dataSet.Valor_Venda.describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# O intervalo de vendas (Valor_Venda) é de 0.44 a 22638. Façamos consulta com retorno em todas as vendas dentro de um range de valores.

# %%
intervaloVendas = dataSet.query('229 < Valor_Venda < 10000')

# %%
intervaloVendas
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 0     CA-2016-152156  2016-11-08   CG-12520     Consumer  United States
# 1     CA-2016-152156  2016-11-08   CG-12520     Consumer  United States
# 3     US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 7     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10    CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# ...              ...         ...        ...          ...            ...
# 9973  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9976  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9979  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9991  CA-2017-121258  2017-02-26   DB-13060     Consumer  United States
# 9993  CA-2017-119914  2017-05-04   CC-12220     Consumer  United States
#
#      Regiao       ID_Produto        Categoria  \
# 0     South  FUR-BO-10001798        Furniture
# ...

# %%
intervaloVendas.Valor_Venda.describe()
# Out:
# count    2357.000000
# mean      766.679142
# std       856.315136
# min       229.544000
# 25%       323.100000
# 50%       490.320000
# 75%       859.200000
# max      9892.740000
# Name: Valor_Venda, dtype: float64

# %%
intervalo3 = intervaloVendas.query('Valor_Venda > 766')

# %%
intervalo3.describe()
# Out:
#        Valor_Venda  Quantidade
# count   687.000000  687.000000
# mean   1615.597817    5.599709
# std    1203.403998    2.498081
# min     767.214000    1.000000
# 25%     914.200000    4.000000
# 50%    1212.960000    5.000000
# 75%    1763.575000    7.000000
# max    9892.740000   14.000000

# %%
intervalo3.head()
# Out:
#          ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 3   US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 7   CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
# 10  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
# 11  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
# 24  CA-2015-106320  2015-09-25   EB-13870  Consumer  United States   West
#
#          ID_Produto   Categoria  \
# 3   FUR-TA-10000577   Furniture
# 7   TEC-PH-10002275  Technology
# 10  FUR-TA-10001539   Furniture
# 11  TEC-PH-10002033  Technology
# 24  FUR-TA-10000577   Furniture
#
#                                      Nome_Produto  Valor_Venda  Quantidade
# 3   Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 7                  Mitel 5320 IP Phone VoIP phone     907.1520         6.0
# 10       Chromcraft Rectangular Conference Tables    1706.1840         9.0
# ...

# %% [markdown]
# ## Verificando Ocorrências de valores em uma coluna

# %%
dataSet.shape
# Out:
# (9994, 11)

# %%
dataSet.ndim
# Out:
# 2

# %%
filtroQtd2 = dataSet[dataSet['Quantidade'].isin([2])]

# %%
filtroQtd2.describe()
# Out:
#        Valor_Venda  Quantidade
# count  2401.000000      2401.0
# mean    120.295510         2.0
# std     252.773342         0.0
# min       0.984000         2.0
# 25%      11.160000         2.0
# 50%      32.480000         2.0
# 75%     121.780000         2.0
# max    4799.984000         2.0

# %%
# SHAPE

dataSet[dataSet['Quantidade'].isin([7])].shape
# Out:
# (606, 11)

# %%
dataSet[dataSet['Quantidade'].isin([7])][:10]
# Out:
#          ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 5   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 21  CA-2016-137330  2016-12-09   KB-16585    Corporate  United States
# 22  CA-2016-137330  2016-12-09   KB-16585    Corporate  United States
# 27  US-2015-150630  2015-09-17   TB-21520     Consumer  United States
# 35  CA-2016-117590  2016-12-08   GH-14485    Corporate  United States
# 53  CA-2016-105816  2016-12-11   JM-15265    Corporate  United States
# 83  CA-2015-149734  2015-09-03   JC-16105    Corporate  United States
# 88  CA-2016-159695  2016-04-05   GM-14455  Home Office  United States
# 96  CA-2017-161018  2017-11-09   PN-18775  Home Office  United States
# 99  CA-2016-158568  2016-08-29   RB-19465  Home Office  United States
#
#      Regiao       ID_Produto        Categoria  \
# 5      West  FUR-FU-10001487        Furniture
# 21  Central  OFF-AR-10000246  Office Supplies
# 22  Central  OFF-AP-10001492  Office Supplies
# ...

# %% [markdown]
# ## Operadores lógios para trabalho com PANDAS

# %%
dataSet[ (dataSet.Segmento == 'Home Office') & (dataSet.Regiao == 'South')]
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 182   CA-2014-158274  2014-11-19   RM-19675  Home Office  United States
# 183   CA-2014-158274  2014-11-19   RM-19675  Home Office  United States
# 184   CA-2014-158274  2014-11-19   RM-19675  Home Office  United States
# 231   US-2017-100930  2017-04-07   CS-12400  Home Office  United States
# 232   US-2017-100930  2017-04-07   CS-12400  Home Office  United States
# ...              ...         ...        ...          ...            ...
# 9805  CA-2016-136322  2016-10-21   AP-10720  Home Office  United States
# 9806  CA-2016-136322  2016-10-21   AP-10720  Home Office  United States
# 9960  CA-2017-141446  2017-09-16   CL-12700  Home Office  United States
# 9970  CA-2015-103772  2015-06-28   MP-17470  Home Office  United States
# 9971  CA-2015-103772  2015-06-28   MP-17470  Home Office  United States
#
#      Regiao       ID_Produto        Categoria  \
# 182   South  TEC-PH-10003273       Technology
# ...

# %%
filtro1 = dataSet[ (dataSet.Segmento == 'Home Office') & (dataSet.Regiao == 'South')]

# %%
filtro1['Valor_Venda'].sum()
# Out:
# 74255.0015

# %%
filtro2 = dataSet [(dataSet.Segmento !='Home Office')]

# %%
filtro2.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
#ultimos registros

filtro3 = dataSet[(dataSet.Segmento == 'Corporate') | (dataSet.Regiao == 'South')].tail()

# %%
filtro3
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 9971  CA-2015-103772  2015-06-28   MP-17470  Home Office  United States
# 9980  US-2015-151435  2015-09-06   SW-20455     Consumer  United States
# 9987  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
# 9988  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
# 9989  CA-2014-110422  2014-01-21   TB-21400     Consumer  United States
#
#      Regiao       ID_Produto        Categoria  \
# 9971  South  OFF-AR-10000538  Office Supplies
# 9980  South  FUR-TA-10001029        Furniture
# 9987  South  TEC-AC-10001539       Technology
# 9988  South  TEC-PH-10004006       Technology
# 9989  South  FUR-FU-10001889        Furniture
#
#                                            Nome_Produto  Valor_Venda  \
# 9971  Boston Model 1800 Electric Pencil Sharpener, Gray      140.750
# 9980                         KI Adjustable-Height Table       85.980
# ...
